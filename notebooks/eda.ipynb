# %% [markdown]
# # EDA — dataset DC1000 (caries)
#
# Exploration : nombre d'images, part de pixels caries, exemples radio + masque.
# Les figures et stats sont ecrites dans `reports/`.

# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))
from src.data import eda
eda.main()

# %%
from IPython.display import Image, display
display(Image('../reports/eda_exemples.png'))
display(Image('../reports/eda_distribution_caries.png'))
